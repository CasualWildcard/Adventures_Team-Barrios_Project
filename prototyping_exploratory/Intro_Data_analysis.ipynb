# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Braxton you are sharing your drive with us, you path to the files will be
#different

#full testing/cleaning will need to be done, as we done not have column names for
#several of these data sets.

ims_consumables_category_lookup = pd.read_csv('/content/drive/Shareddrives/CS 4306 Barrios Project/csv Files/ims_consumables_category_lookup.csv')

inventory_mgmt_system_consumables = pd.read_csv('/content/drive/Shareddrives/CS 4306 Barrios Project/csv Files/inventory_mgmt_system_consumables_20220101-20230905.csv')

iss_flight_plan_2022_2025 = pd.read_csv('/content/drive/Shareddrives/CS 4306 Barrios Project/csv Files/iss_flight_plan_20220101-20251231.csv')

iss_flight_plan_crew_2022_2025 = pd.read_csv('/content/drive/Shareddrives/CS 4306 Barrios Project/csv Files/iss_flight_plan_crew_20220101-20251321.csv')

iss_flight_plan_crew_nationality = pd.read_csv('/content/drive/Shareddrives/CS 4306 Barrios Project/csv Files/iss_flight_plan_crew_nationality_lookup.csv')

rates_definition = pd.read_csv('/content/drive/Shareddrives/CS 4306 Barrios Project/csv Files/rates_definition.csv')

rsa_consumable_water_summary = pd.read_csv('/content/drive/Shareddrives/CS 4306 Barrios Project/csv Files/rsa_consumable_water_summary_20220103-20230828.csv')

stored_items_only_inventory_mgmt_system_consumables = pd.read_csv('/content/drive/Shareddrives/CS 4306 Barrios Project/csv Files/stored_items_only_inventory_mgmt_system_consumables_20220101-20230905.csv')

tank_capacity_definition = pd.read_csv('/content/drive/Shareddrives/CS 4306 Barrios Project/csv Files/tank_capacity_definition.csv')

thresholds_limits_definition = pd.read_csv('/content/drive/Shareddrives/CS 4306 Barrios Project/csv Files/thresholds_limits_definition.csv')

us_rs_weekly_consumable_gas_summary = pd.read_csv('/content/drive/Shareddrives/CS 4306 Barrios Project/csv Files/us_rs_weekly_consumable_gas_summary_20220102-20230903.csv')

us_weekly_consumable_water_summary = pd.read_csv('/content/drive/Shareddrives/CS 4306 Barrios Project/csv Files/us_weekly_consumable_water_summary_20220102-20230903.csv')

# %%
inventory_mgmt_system_consumables.head()
# Out:
#    2022-01-01 10:01:08.690  364155  265  /0/101/265/364155/  3  \
# 0  2022-01-01 10:01:08.690  364156  265  /0/101/265/364156/  3
# 1  2022-01-01 10:01:08.690  364157  265  /0/101/265/364157/  3
# 2  2022-01-01 10:01:08.690  364158  265  /0/101/265/364158/  3
# 3  2022-01-01 10:01:08.690  364160  265  /0/101/265/364160/  3
# 4  2022-01-01 10:01:08.690  364161  265  /0/101/265/364161/  3
#
#    Storage Location  11Ф615.8720А55-20  1180  ФГБ1ГА  Russian Space Agency  \
# 0  Storage Location  11Ф615.8720А55-20  1181  ФГБ1ГА  Russian Space Agency
# 1  Storage Location  11Ф615.8720А55-20  1182  ФГБ1ГА  Russian Space Agency
# 2  Storage Location  11Ф615.8720А55-10  1182  ФГБ1ГА  Russian Space Agency
# 3  Storage Location  11Ф615.8720А55-20  1184  ФГБ1ГА  Russian Space Agency
# 4  Storage Location  11Ф615.8720А55-20  1185  ФГБ1ГА  Russian Space Agency
#
#    ...  Stowed 1.1 1.2  SM Hygiene Sanitary Equipment  АсСУ  \
# 0  ...  Stowed   1   1  SM Hygiene Sanitary Equipment  АсСУ
# ...

# %%
inventory_mgmt_system_consumables.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5790368 entries, 0 to 5790367
# Data columns (total 41 columns):
#  #   Column                                 Dtype
# ---  ------                                 -----
#  0   2022-01-01 10:01:08.690                object
#  1   364155                                 int64
#  2   265                                    int64
#  3   /0/101/265/364155/                     object
#  4   3                                      int64
#  5   Storage Location                       object
#  6   11Ф615.8720А55-20                      object
#  7   1180                                   object
#  8   ФГБ1ГА                                 object
#  9   Russian Space Agency                   object
#  10  RSA00                                  object
#  11  Корпус КТО                             object
#  12  Корпус КТО.1                           object
#  13  SOLID WESTE CONTAINER BODY             object
# ...

# %%
ims_consumables_category_lookup.head()
# Out:
#     category_name  categoryID  module_name  moduleID unique_cat_mod_ID
# 0             EDV           1  Consumables         2               2-1
# 1  Pretreat Tanks           2  Consumables         2               2-2
# 2             KTO           3  Consumables         2               2-3
# 3     ACY Inserts           4  Consumables         2               2-4
# 4  Filter Inserts           5  Consumables         2               2-5
